# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities :
        cities.append(city)

# %%
# Import the requests library.6.2.2
import requests

# %%
# Import the API key.
from config import weather_api_keys

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_keys

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.

citi_data = [] 



# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
 # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.

        citi_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass 

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | synya
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | biak
# Processing Record 18 of Set 1 | nome
# Processing Record 19 of Set 1 | goderich
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | bambari
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | havre-saint-pierre
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | strezhevoy
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | amahai
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | walvis bay
# Processing Record 35 of Set 1 | englehart
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | vilyuysk
# Processing Record 39 of Set 1 | road town
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | vestmannaeyjar
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | salinopolis
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | bethel
# Processing Record 51 of Set 1 | tosya
# Processing Record 52 of Set 1 | kodiak
# Processing Record 53 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 54 of Set 1 | punta arenas
# Processing Record 55 of Set 1 | nha trang
# Processing Record 56 of Set 1 | ancud
# Processing Record 57 of Set 1 | yellowknife
# Processing Record 58 of Set 1 | teguldet
# Processing Record 59 of Set 1 | andenes
# Processing Record 60 of Set 1 | rosetta
# Processing Record 61 of Set 1 | necochea
# Processing Record 62 of Set 1 | areni
# Processing Record 1 of Set 2 | yangjiang
# Processing Record 2 of Set 2 | cabo san lucas
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | piney green
# Processing Record 5 of Set 2 | naryan-mar
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | sinjai
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | archidona
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | carbonia
# Processing Record 12 of Set 2 | kavieng
# Processing Record 13 of Set 2 | nueva germania
# Processing Record 14 of Set 2 | mazatlan
# Processing Record 15 of Set 2 | cumra
# Processing Record 16 of Set 2 | rikitea
# Processing Record 17 of Set 2 | nishihara
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | amapa
# Processing Record 20 of Set 2 | mende
# Processing Record 21 of Set 2 | cueto
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | san patricio
# Processing Record 24 of Set 2 | egvekinot
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | verkhoyansk
# Processing Record 28 of Set 2 | sale
# Processing Record 29 of Set 2 | guerrero negro
# Processing Record 30 of Set 2 | gat
# Processing Record 31 of Set 2 | lielvarde
# Processing Record 32 of Set 2 | pacifica
# Processing Record 33 of Set 2 | kalmunai
# Processing Record 34 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | malanville
# Processing Record 37 of Set 2 | yar-sale
# Processing Record 38 of Set 2 | weinan
# Processing Record 39 of Set 2 | privolnaya
# Processing Record 40 of Set 2 | orocue
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | shenkursk
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | muisne
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | salym
# Processing Record 48 of Set 2 | rosita
# Processing Record 49 of Set 2 | talara
# Processing Record 50 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | nenjiang
# Processing Record 6 of Set 3 | stange
# Processing Record 7 of Set 3 | tahta
# Processing Record 8 of Set 3 | ayan
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | carikar
# City not found. Skipping...
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | mae hong son
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | beira
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | rameswaram
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | podgornoye
# Processing Record 21 of Set 3 | wanning
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | komsomolskiy
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | mapiripan
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | usogorsk
# Processing Record 32 of Set 3 | campbell river
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | melchor de mencos
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | saint-louis
# Processing Record 37 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | rosarito
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | gamboma
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | jalu
# Processing Record 45 of Set 3 | rostock
# Processing Record 46 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 3 | srednekolymsk
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | sept-iles
# Processing Record 2 of Set 4 | avera
# Processing Record 3 of Set 4 | skelleftea
# Processing Record 4 of Set 4 | turochak
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | pimenteiras
# Processing Record 7 of Set 4 | pyaozerskiy
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | xuddur
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | jacqueville
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | bluff
# Processing Record 15 of Set 4 | luanda
# Processing Record 16 of Set 4 | vaini
# Processing Record 17 of Set 4 | utete
# Processing Record 18 of Set 4 | nelson bay
# Processing Record 19 of Set 4 | korla
# Processing Record 20 of Set 4 | shache
# Processing Record 21 of Set 4 | mount isa
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | nanortalik
# Processing Record 24 of Set 4 | bubaque
# Processing Record 25 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | vazante
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | ahtopol
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | panaba
# Processing Record 31 of Set 4 | kyzyl
# Processing Record 32 of Set 4 | sagaing
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | oistins
# Processing Record 35 of Set 4 | vostok
# Processing Record 36 of Set 4 | sao joao da barra
# Processing Record 37 of Set 4 | tongliao
# Processing Record 38 of Set 4 | terrace
# Processing Record 39 of Set 4 | monticello
# Processing Record 40 of Set 4 | akom
# Processing Record 41 of Set 4 | balkanabat
# Processing Record 42 of Set 4 | maracacume
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | hobyo
# Processing Record 46 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 4 | pundaguitan
# Processing Record 48 of Set 4 | bitung
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | antofagasta
# Processing Record 1 of Set 5 | sault sainte marie
# Processing Record 2 of Set 5 | doha
# Processing Record 3 of Set 5 | hualmay
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | vangaindrano
# Processing Record 7 of Set 5 | nyrob
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | paso de los toros
# Processing Record 10 of Set 5 | ransang
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | shar
# Processing Record 13 of Set 5 | inirida
# Processing Record 14 of Set 5 | gospic
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | sokolo
# Processing Record 17 of Set 5 | amarpatan
# Processing Record 18 of Set 5 | pochutla
# Processing Record 19 of Set 5 | penzance
# Processing Record 20 of Set 5 | san julian
# Processing Record 21 of Set 5 | grand-santi
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | marsh harbour
# Processing Record 26 of Set 5 | sharjah
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | mahebourg
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | iskateley
# Processing Record 31 of Set 5 | belmonte
# Processing Record 32 of Set 5 | donskoye
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | songea
# Processing Record 35 of Set 5 | san juan
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | tonantins
# Processing Record 38 of Set 5 | sulurpeta
# City not found. Skipping...
# Processing Record 39 of Set 5 | boyolangu
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | opuwo
# Processing Record 42 of Set 5 | bam
# Processing Record 43 of Set 5 | buala
# Processing Record 44 of Set 5 | brae
# Processing Record 45 of Set 5 | oktyabrskiy
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | bonfim
# Processing Record 49 of Set 5 | puerto penasco
# Processing Record 50 of Set 5 | poros
# Processing Record 1 of Set 6 | novikovo
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | abu samrah
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | viedma
# Processing Record 7 of Set 6 | naze
# Processing Record 8 of Set 6 | bara
# Processing Record 9 of Set 6 | sibuco
# Processing Record 10 of Set 6 | zarate
# Processing Record 11 of Set 6 | lakes entrance
# Processing Record 12 of Set 6 | fuerte olimpo
# Processing Record 13 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | ambon
# Processing Record 17 of Set 6 | wanaka
# Processing Record 18 of Set 6 | port lincoln
# Processing Record 19 of Set 6 | chardara
# Processing Record 20 of Set 6 | ouro preto do oeste
# Processing Record 21 of Set 6 | prieska
# Processing Record 22 of Set 6 | ubud
# Processing Record 23 of Set 6 | ocos
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 6 | azangaro
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | aklavik
# Processing Record 29 of Set 6 | santa cruz
# Processing Record 30 of Set 6 | mounana
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | zhigansk
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | new norfolk
# Processing Record 35 of Set 6 | yaan
# Processing Record 36 of Set 6 | port macquarie
# Processing Record 37 of Set 6 | ust-omchug
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 6 | gimli
# Processing Record 42 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 6 | izhma
# Processing Record 44 of Set 6 | leh
# Processing Record 45 of Set 6 | sao felix do xingu
# Processing Record 46 of Set 6 | kampot
# Processing Record 47 of Set 6 | maragogi
# Processing Record 48 of Set 6 | trincomalee
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | rivadavia
# Processing Record 1 of Set 7 | kamen-rybolov
# Processing Record 2 of Set 7 | mercedes
# Processing Record 3 of Set 7 | vila franca do campo
# Processing Record 4 of Set 7 | monrovia
# Processing Record 5 of Set 7 | wukari
# Processing Record 6 of Set 7 | charters towers
# Processing Record 7 of Set 7 | peterhead
# Processing Record 8 of Set 7 | bagan
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | anadyr
# Processing Record 11 of Set 7 | north myrtle beach
# Processing Record 12 of Set 7 | sandwick
# Processing Record 13 of Set 7 | tuatapere
# Processing Record 14 of Set 7 | las animas
# Processing Record 15 of Set 7 | metairie
# Processing Record 16 of Set 7 | latung
# Processing Record 17 of Set 7 | oga
# Processing Record 18 of Set 7 | phonhong
# Processing Record 19 of Set 7 | canton
# Processing Record 20 of Set 7 | saint thomas mount
# Processing Record 21 of Set 7 | labuhan
# Processing Record 22 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 7 | san jose
# Processing Record 24 of Set 7 | port hedland
# Processing Record 25 of Set 7 | hammerfest
# Processing Record 26 of Set 7 | brigantine
# Processing Record 27 of Set 7 | san rafael
# Processing Record 28 of Set 7 | gladstone
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 7 | kloulklubed
# Processing Record 32 of Set 7 | berezovyy
# Processing Record 33 of Set 7 | mogocha
# Processing Record 34 of Set 7 | sikonge
# Processing Record 35 of Set 7 | caravelas
# Processing Record 36 of Set 7 | muborak
# Processing Record 37 of Set 7 | san angelo
# Processing Record 38 of Set 7 | presidente franco
# Processing Record 39 of Set 7 | presidencia roque saenz pena
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | manggar
# Processing Record 42 of Set 7 | yamada
# Processing Record 43 of Set 7 | khotynets
# Processing Record 44 of Set 7 | antalaha
# Processing Record 45 of Set 7 | olafsvik
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | kamaishi
# Processing Record 48 of Set 7 | cuijk
# Processing Record 49 of Set 7 | zhanakorgan
# Processing Record 50 of Set 7 | sahuaripa
# Processing Record 1 of Set 8 | poli
# Processing Record 2 of Set 8 | baykalovo
# Processing Record 3 of Set 8 | nogliki
# Processing Record 4 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 8 | porto novo
# Processing Record 6 of Set 8 | mount pleasant
# Processing Record 7 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 8 | ixtapa
# Processing Record 9 of Set 8 | isangel
# Processing Record 10 of Set 8 | ponta delgada
# Processing Record 11 of Set 8 | mandalgovi
# Processing Record 12 of Set 8 | mayumba
# Processing Record 13 of Set 8 | clyde river
# Processing Record 14 of Set 8 | portland
# Processing Record 15 of Set 8 | rosario do sul
# Processing Record 16 of Set 8 | qui nhon
# Processing Record 17 of Set 8 | barpathar
# Processing Record 18 of Set 8 | angleton
# Processing Record 19 of Set 8 | waipawa
# Processing Record 20 of Set 8 | ormara
# Processing Record 21 of Set 8 | crotone
# Processing Record 22 of Set 8 | vicosa
# Processing Record 23 of Set 8 | puerto el triunfo
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | zhurivka
# Processing Record 26 of Set 8 | adilcevaz
# Processing Record 27 of Set 8 | eyl
# Processing Record 28 of Set 8 | bilma
# Processing Record 29 of Set 8 | chirongui
# Processing Record 30 of Set 8 | broome
# Processing Record 31 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 32 of Set 8 | vuktyl
# Processing Record 33 of Set 8 | ilorin
# Processing Record 34 of Set 8 | diffa
# Processing Record 35 of Set 8 | toucheng
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | zabaykalsk
# Processing Record 38 of Set 8 | kewanee
# Processing Record 39 of Set 8 | hirna
# Processing Record 40 of Set 8 | touros
# Processing Record 41 of Set 8 | a
# City not found. Skipping...
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | ivankiv
# Processing Record 44 of Set 8 | griffith
# Processing Record 45 of Set 8 | lukang
# Processing Record 46 of Set 8 | sonepur
# Processing Record 47 of Set 8 | batsfjord
# Processing Record 48 of Set 8 | sabancuy
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | ishigaki
# Processing Record 1 of Set 9 | inongo
# Processing Record 2 of Set 9 | saint-francois
# Processing Record 3 of Set 9 | mankera
# Processing Record 4 of Set 9 | madison
# Processing Record 5 of Set 9 | yambio
# Processing Record 6 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 9 | constitucion
# Processing Record 8 of Set 9 | lata
# Processing Record 9 of Set 9 | faya
# Processing Record 10 of Set 9 | tautira
# Processing Record 11 of Set 9 | kudal
# Processing Record 12 of Set 9 | severo-kurilsk
# Processing Record 13 of Set 9 | rongcheng
# Processing Record 14 of Set 9 | crestview
# Processing Record 15 of Set 9 | mahibadhoo
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | deputatskiy
# Processing Record 18 of Set 9 | amuntai
# Processing Record 19 of Set 9 | kijang
# Processing Record 20 of Set 9 | awjilah
# Processing Record 21 of Set 9 | palora
# Processing Record 22 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 9 | shingu
# Processing Record 24 of Set 9 | bodden town
# Processing Record 25 of Set 9 | tisul
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | saint-joseph
# Processing Record 28 of Set 9 | san vicente
# Processing Record 29 of Set 9 | mackay
# Processing Record 30 of Set 9 | coffs harbour
# Processing Record 31 of Set 9 | hambantota
# Processing Record 32 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 9 | tateyama
# Processing Record 34 of Set 9 | noyabrsk
# Processing Record 35 of Set 9 | caninde
# Processing Record 36 of Set 9 | baboua
# City not found. Skipping...
# Processing Record 37 of Set 9 | abu kamal
# Processing Record 38 of Set 9 | kidal
# Processing Record 39 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 9 | lasa
# Processing Record 41 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | miranda
# Processing Record 43 of Set 9 | killybegs
# Processing Record 44 of Set 9 | harper
# Processing Record 45 of Set 9 | alexandria
# Processing Record 46 of Set 9 | shillong
# Processing Record 47 of Set 9 | chapais
# Processing Record 48 of Set 9 | talcahuano
# Processing Record 49 of Set 9 | carutapera
# Processing Record 50 of Set 9 | altus
# Processing Record 1 of Set 10 | ambilobe
# Processing Record 2 of Set 10 | kachug
# Processing Record 3 of Set 10 | rawson
# Processing Record 4 of Set 10 | abu dhabi
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | talnakh
# Processing Record 7 of Set 10 | ewa beach
# Processing Record 8 of Set 10 | cap malheureux
# Processing Record 9 of Set 10 | peniche
# Processing Record 10 of Set 10 | kilindoni
# Processing Record 11 of Set 10 | lebowakgomo
# Processing Record 12 of Set 10 | vanimo
# Processing Record 13 of Set 10 | weligama
# Processing Record 14 of Set 10 | teya
# Processing Record 15 of Set 10 | cananea
# Processing Record 16 of Set 10 | haverfordwest
# Processing Record 17 of Set 10 | kisesa
# Processing Record 18 of Set 10 | port augusta
# Processing Record 19 of Set 10 | yarada
# Processing Record 20 of Set 10 | vao
# Processing Record 21 of Set 10 | mandurah
# Processing Record 22 of Set 10 | banjarmasin
# Processing Record 23 of Set 10 | tura
# Processing Record 24 of Set 10 | tomatlan
# Processing Record 25 of Set 10 | chibombo
# Processing Record 26 of Set 10 | biryusinsk
# Processing Record 27 of Set 10 | high rock
# Processing Record 28 of Set 10 | estreito
# Processing Record 29 of Set 10 | ozernovskiy
# Processing Record 30 of Set 10 | anda
# Processing Record 31 of Set 10 | los llanos de aridane
# Processing Record 32 of Set 10 | pisco
# Processing Record 33 of Set 10 | tezu
# Processing Record 34 of Set 10 | arman
# Processing Record 35 of Set 10 | kuala terengganu
# Processing Record 36 of Set 10 | davila
# Processing Record 37 of Set 10 | hearst
# Processing Record 38 of Set 10 | chulumani
# Processing Record 39 of Set 10 | kralendijk
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | astana
# Processing Record 42 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | ridgecrest
# Processing Record 44 of Set 10 | port hawkesbury
# Processing Record 45 of Set 10 | wuwei
# Processing Record 46 of Set 10 | tilichiki
# Processing Record 47 of Set 10 | balabag
# Processing Record 48 of Set 10 | ca mau
# Processing Record 49 of Set 10 | cervo
# Processing Record 50 of Set 10 | duku
# Processing Record 1 of Set 11 | manyana
# Processing Record 2 of Set 11 | lavrentiya
# Processing Record 3 of Set 11 | malinovskiy
# Processing Record 4 of Set 11 | konevo
# Processing Record 5 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 11 | port moresby
# Processing Record 7 of Set 11 | energetik
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | eluru
# Processing Record 10 of Set 11 | siguiri
# Processing Record 11 of Set 11 | port maria
# Processing Record 12 of Set 11 | maningrida
# Processing Record 13 of Set 11 | macherla
# Processing Record 14 of Set 11 | shizunai
# Processing Record 15 of Set 11 | baykit
# Processing Record 16 of Set 11 | kiunga
# Processing Record 17 of Set 11 | little current
# Processing Record 18 of Set 11 | bowen
# Processing Record 19 of Set 11 | makakilo city
# Processing Record 20 of Set 11 | bayaguana
# Processing Record 21 of Set 11 | sioux lookout
# Processing Record 22 of Set 11 | mabaruma
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | mareeba
# Processing Record 25 of Set 11 | farmington
# Processing Record 26 of Set 11 | jacareacanga
# Processing Record 27 of Set 11 | yenotayevka
# Processing Record 28 of Set 11 | codrington
# Processing Record 29 of Set 11 | la ronge
# Processing Record 30 of Set 11 | leningradskiy
# Processing Record 31 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 11 | takoradi
# Processing Record 33 of Set 11 | tiznit
# Processing Record 34 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 11 | suining
# Processing Record 36 of Set 11 | fomboni
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | verkh-usugli
# Processing Record 39 of Set 11 | kristiinankaupunki
# Processing Record 40 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 11 | zyryanka
# Processing Record 42 of Set 11 | montemor-o-novo
# Processing Record 43 of Set 11 | krasnoselkup
# Processing Record 44 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 45 of Set 11 | havelock
# Processing Record 46 of Set 11 | alirajpur
# Processing Record 47 of Set 11 | lobatse
# Processing Record 48 of Set 11 | male
# Processing Record 49 of Set 11 | purpe
# Processing Record 50 of Set 11 | conselheiro pena
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | winder
# Processing Record 3 of Set 12 | irtyshskiy
# Processing Record 4 of Set 12 | the valley
# Processing Record 5 of Set 12 | kalmar
# Processing Record 6 of Set 12 | lac du bonnet
# Processing Record 7 of Set 12 | nchelenge
# Processing Record 8 of Set 12 | hami
# Processing Record 9 of Set 12 | tambopata
# Processing Record 10 of Set 12 | grand forks
# Processing Record 11 of Set 12 | arroyo
# Processing Record 12 of Set 12 | boa vista
# Processing Record 13 of Set 12 | tabou
# Processing Record 14 of Set 12 | kananga
# Processing Record 15 of Set 12 | chitral
# Processing Record 16 of Set 12 | russell
# Processing Record 17 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 12 | tucurui
# Processing Record 19 of Set 12 | ayiasos
# City not found. Skipping...
# Processing Record 20 of Set 12 | ushtobe
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | yeppoon
# Processing Record 23 of Set 12 | bahia blanca
# Processing Record 24 of Set 12 | nerchinskiy zavod
# Processing Record 25 of Set 12 | medvode
# Processing Record 26 of Set 12 | san jeronimo
# Processing Record 27 of Set 12 | severnyy-kospashskiy
# Processing Record 28 of Set 12 | bandarbeyla
# Processing Record 29 of Set 12 | raga
# Processing Record 30 of Set 12 | pudozh
# Processing Record 31 of Set 12 | crixas
# Processing Record 32 of Set 12 | pizarro
# Processing Record 33 of Set 12 | savinskiy
# Processing Record 34 of Set 12 | taiyuan
# Processing Record 35 of Set 12 | lorengau
# Processing Record 36 of Set 12 | navalmoral de la mata
# Processing Record 37 of Set 12 | warrington
# Processing Record 38 of Set 12 | pangai
# Processing Record 39 of Set 12 | atambua
# Processing Record 40 of Set 12 | tongzi
# Processing Record 41 of Set 12 | sakakah
# Processing Record 42 of Set 12 | palaikastron
# Processing Record 43 of Set 12 | buraydah
# Processing Record 44 of Set 12 | mulege
# Processing Record 45 of Set 12 | sarangani
# Processing Record 46 of Set 12 | lazaro cardenas
# Processing Record 47 of Set 12 | san andres
# Processing Record 48 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 12 | araouane
# Processing Record 50 of Set 12 | invercargill
# Processing Record 1 of Set 13 | havre
# Processing Record 2 of Set 13 | bismarck
# Processing Record 3 of Set 13 | adrar
# Processing Record 4 of Set 13 | boueni
# Processing Record 5 of Set 13 | berikulskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | torrington
# Processing Record 7 of Set 13 | merauke
# Processing Record 8 of Set 13 | bose
# Processing Record 9 of Set 13 | moindou
# Processing Record 10 of Set 13 | quelimane
# Processing Record 11 of Set 13 | kirovsk
# Processing Record 12 of Set 13 | santa lucia
# Processing Record 13 of Set 13 | takapau
# Processing Record 14 of Set 13 | turukhansk
# Processing Record 15 of Set 13 | creel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(citi_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Ilulissat  69.2167  -51.1000     39.22        56         100       16.11
# 1       Synya  65.3718   58.0387     12.87        86         100       17.34
# 2      Dikson  73.5069   80.5464     -6.72        96         100       13.06
# 3   Busselton -33.6500  115.3333     92.28        27           0        4.61
# 4        Biak  -0.9131  122.8766     79.36        79         100        3.11
# 5        Nome  64.5011 -165.4064     -9.33        64           0        0.00
# 6    Goderich  43.7501  -81.7165     23.92        79         100       21.85
# 7  Bredasdorp -34.5322   20.0403     63.28        94          65        5.75
# 8    Tasiilaq  65.6145  -37.6368     32.16        97         100       12.59
# 9      Hobart -42.8794  147.3294     76.01        50          75        1.01
#
#   Country                 Date
# 0      GL  2022-01-20 02:37:07
# 1      RU  2022-01-20 02:37:07
# 2      RU  2022-01-20 02:37:07
# 3      AU  2022-01-20 02:37:07
# 4      ID  2022-01-20 02:37:08
# 5      US  2022-01-20 02:37:08
# 6      CA  2022-01-20 02:35:47
# 7      ZA  2022-01-20 02:37:08
# 8      GL  2022-01-20 02:37:08
# 9      AU  2022-01-20 02:37:09

# %%
new_column_order=["City","Country","Date","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Ilulissat      GL  2022-01-20 02:37:07  69.2167  -51.1000     39.22
# 1          Synya      RU  2022-01-20 02:37:07  65.3718   58.0387     12.87
# 2         Dikson      RU  2022-01-20 02:37:07  73.5069   80.5464     -6.72
# 3      Busselton      AU  2022-01-20 02:37:07 -33.6500  115.3333     92.28
# 4           Biak      ID  2022-01-20 02:37:08  -0.9131  122.8766     79.36
# ..           ...     ...                  ...      ...       ...       ...
# 577      Kirovsk      UA  2022-01-20 02:55:57  48.6375   38.6428      6.94
# 578  Santa Lucia      ES  2022-01-20 02:55:57  27.9117  -15.5407     59.76
# 579      Takapau      NZ  2022-01-20 02:55:58 -40.0333  176.3500     72.73
# 580   Turukhansk      RU  2022-01-20 02:55:58  65.8167   87.9833      8.80
# 581        Creel      MX  2022-01-20 02:55:58  27.7500 -107.6333     37.58
#
#      Humidity  Cloudiness  Wind Speed
# 0          56         100       16.11
# 1          86         100       17.34
# 2          96         100       13.06
# 3          27           0        4.61
# 4          79         100        3.11
# ..        ...         ...         ...
# 577        97          86        3.71
# 578        52           0        5.75
# 579        36         100        4.09
# 580        95         100       11.05
# 581        70          94        3.76
#
# [582 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Read Data 
file_to_load="weather_data/cities.csv"
city_data_df=pd.read_csv(file_to_load)
city_data_df
# Out:
#      City_ID         City Country                 Date      Lat       Lng  \
# 0          0    Ilulissat      GL  2022-01-20 02:37:07  69.2167  -51.1000
# 1          1        Synya      RU  2022-01-20 02:37:07  65.3718   58.0387
# 2          2       Dikson      RU  2022-01-20 02:37:07  73.5069   80.5464
# 3          3    Busselton      AU  2022-01-20 02:37:07 -33.6500  115.3333
# 4          4         Biak      ID  2022-01-20 02:37:08  -0.9131  122.8766
# ..       ...          ...     ...                  ...      ...       ...
# 577      577      Kirovsk      UA  2022-01-20 02:55:57  48.6375   38.6428
# 578      578  Santa Lucia      ES  2022-01-20 02:55:57  27.9117  -15.5407
# 579      579      Takapau      NZ  2022-01-20 02:55:58 -40.0333  176.3500
# 580      580   Turukhansk      RU  2022-01-20 02:55:58  65.8167   87.9833
# 581      581        Creel      MX  2022-01-20 02:55:58  27.7500 -107.6333
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       39.22        56         100       16.11
# 1       12.87        86         100       17.34
# 2       -6.72        96         100       13.06
# 3       92.28        27           0        4.61
# 4       79.36        79         100        3.11
# ..        ...       ...         ...         ...
# 577      6.94        97          86        3.71
# 578     59.76        52           0        5.75
# 579     72.73        36         100        4.09
# 580      8.80        95         100       11.05
# 581     37.58        70          94        3.76
#
# [582 rows x 10 columns]

# %%
# Extract relevant fields from the DataFrame for plotting. 6.3.1
lats=city_data_df["Lat"]
max_temp=city_data_df["Max Temp"]
humidity=city_data_df["Humidity"]
cloudiness=city_data_df["Cloudiness"]
wind_speed= city_data_df["Wind Speed"]

# %%
#import time
import time
#Build Scatter plot for latitude vs. max temerature
plt.scatter(lats,max_temp,edgecolor="black",color="coral",linewidth=1,marker="o", alpha=0.8, label="Cities")
#Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.xlabel("Latitude")
#plt.ylabel(" Max Temp")
plt.grid(True)
#Save the figure
plt.savefig("weather_data/lat_max.PNG")
#shor Plot
plt.show()

# %%
#Build Scatter plot for latitude vs. max temerature
plt.scatter(lats,humidity,edgecolor="black",color="green",linewidth=1,marker="o", alpha=0.8, label="Cities")
#Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.xlabel("Latitude")
#plt.ylabel(" Max Temp")
plt.grid(True)
#Save the figure
plt.savefig("weather_data/lat_hum.PNG")
#shor Plot
plt.show()

# %%
#Build Scatter plot for latitude vs. max temerature
plt.scatter(lats,cloudiness,edgecolor="black",color="yellow",linewidth=1,marker="o", alpha=0.8, label="Cities")
#Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.xlabel("Latitude")
#plt.ylabel(" Max Temp")
plt.grid(True)
#Save the figure
plt.savefig("weather_data/lat_cloud.PNG")
#shor Plot
plt.show()

# %%
#Build Scatter plot for latitude vs. max temerature
plt.scatter(lats,wind_speed,edgecolor="black",color="purple",linewidth=1,marker="o", alpha=0.8, label="Cities")
#Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.xlabel("Latitude")
#plt.ylabel(" Max Temp")
plt.grid(True)
#Save the figure
plt.savefig("weather_data/lat_wind.PNG")
#shor Plot
plt.show()
