# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities :
        cities.append(city)

# %%
# Import the requests library
import requests

# %%
# Import the API key.
from config import weather_api_keys

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_keys

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.

citi_data = [] 



# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
 # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.

        citi_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass 

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sayama
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | kropotkin
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | hakkari
# Processing Record 15 of Set 1 | cravo norte
# Processing Record 16 of Set 1 | acarau
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | anadyr
# Processing Record 20 of Set 1 | nizhyn
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | portland
# Processing Record 27 of Set 1 | novobirilyussy
# Processing Record 28 of Set 1 | kimbe
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | havre-saint-pierre
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | krasnoarmeysk
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | zambezi
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | sesheke
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | srednekolymsk
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | la ronge
# Processing Record 42 of Set 1 | koscierzyna
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | cockburn town
# Processing Record 45 of Set 1 | charters towers
# Processing Record 46 of Set 1 | urrao
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | isla vista
# Processing Record 5 of Set 2 | novo aripuana
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | khowst
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | shimoda
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | makung
# City not found. Skipping...
# Processing Record 15 of Set 2 | diego de almagro
# Processing Record 16 of Set 2 | kokstad
# Processing Record 17 of Set 2 | yayva
# Processing Record 18 of Set 2 | bathsheba
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | valdivia
# Processing Record 26 of Set 2 | koslan
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | husavik
# Processing Record 29 of Set 2 | alugan
# Processing Record 30 of Set 2 | verkhnevilyuysk
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | yushan
# Processing Record 35 of Set 2 | peace river
# Processing Record 36 of Set 2 | razole
# Processing Record 37 of Set 2 | nelson bay
# Processing Record 38 of Set 2 | kattivakkam
# Processing Record 39 of Set 2 | atasu
# Processing Record 40 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 2 | faya
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | wuzhou
# Processing Record 44 of Set 2 | caborca
# Processing Record 45 of Set 2 | oktyabrskoye
# Processing Record 46 of Set 2 | digha
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | ust-ordynskiy
# Processing Record 50 of Set 2 | harbour breton
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | vaitape
# Processing Record 3 of Set 3 | rocha
# Processing Record 4 of Set 3 | a
# City not found. Skipping...
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | lebyazhye
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | te anau
# Processing Record 10 of Set 3 | burns lake
# Processing Record 11 of Set 3 | mlonggo
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | penjamillo
# City not found. Skipping...
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | presidencia roque saenz pena
# Processing Record 16 of Set 3 | atyashevo
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | tautira
# Processing Record 20 of Set 3 | ekibastuz
# Processing Record 21 of Set 3 | kultuk
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | touros
# Processing Record 24 of Set 3 | swift current
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | almaznyy
# Processing Record 27 of Set 3 | sala
# Processing Record 28 of Set 3 | praia da vitoria
# Processing Record 29 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | muncar
# Processing Record 32 of Set 3 | piazza armerina
# Processing Record 33 of Set 3 | sao miguel do araguaia
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | pangnirtung
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | makakilo city
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | whitecourt
# Processing Record 41 of Set 3 | zhicheng
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | saurimo
# Processing Record 44 of Set 3 | sorland
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | payo
# Processing Record 48 of Set 3 | hofn
# Processing Record 49 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 50 of Set 3 | hamilton
# Processing Record 1 of Set 4 | kloulklubed
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | betioky
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | mahon
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | mackenzie
# Processing Record 14 of Set 4 | prainha
# Processing Record 15 of Set 4 | walvis bay
# Processing Record 16 of Set 4 | berekua
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | bandarbeyla
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | pangody
# Processing Record 21 of Set 4 | la roche-sur-yon
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | don sak
# Processing Record 24 of Set 4 | qui nhon
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | comodoro rivadavia
# Processing Record 27 of Set 4 | acambay
# Processing Record 28 of Set 4 | shahrud
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | onguday
# Processing Record 31 of Set 4 | babati
# Processing Record 32 of Set 4 | noshiro
# Processing Record 33 of Set 4 | yarada
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | inirida
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | kyzyl-suu
# Processing Record 38 of Set 4 | osoyoos
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | mapiripan
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | yasnyy
# Processing Record 44 of Set 4 | la trinite
# Processing Record 45 of Set 4 | liepaja
# Processing Record 46 of Set 4 | nuqui
# Processing Record 47 of Set 4 | tosya
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | rebrikha
# Processing Record 50 of Set 4 | laguna
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | kvarkeno
# Processing Record 5 of Set 5 | mahebourg
# Processing Record 6 of Set 5 | zheleznodorozhnyy
# Processing Record 7 of Set 5 | deputatskiy
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | noumea
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 14 of Set 5 | varadero
# Processing Record 15 of Set 5 | cerritos
# Processing Record 16 of Set 5 | yar-sale
# Processing Record 17 of Set 5 | srandakan
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | ugoofaaru
# Processing Record 20 of Set 5 | bud
# Processing Record 21 of Set 5 | mana
# Processing Record 22 of Set 5 | banepa
# Processing Record 23 of Set 5 | adrar
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | bonthe
# Processing Record 26 of Set 5 | muroto
# Processing Record 27 of Set 5 | elizabeth city
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | ndele
# Processing Record 30 of Set 5 | kroya
# Processing Record 31 of Set 5 | chokurdakh
# Processing Record 32 of Set 5 | antofagasta
# Processing Record 33 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | luocheng
# Processing Record 36 of Set 5 | inhambane
# Processing Record 37 of Set 5 | khaga
# Processing Record 38 of Set 5 | poronaysk
# Processing Record 39 of Set 5 | novyy urengoy
# Processing Record 40 of Set 5 | isangel
# Processing Record 41 of Set 5 | wilmington
# Processing Record 42 of Set 5 | ixtlahuacan del rio
# Processing Record 43 of Set 5 | washington
# Processing Record 44 of Set 5 | takoradi
# Processing Record 45 of Set 5 | hellvik
# Processing Record 46 of Set 5 | peniche
# Processing Record 47 of Set 5 | sao felix do xingu
# Processing Record 48 of Set 5 | daru
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | diamantino
# Processing Record 1 of Set 6 | muros
# Processing Record 2 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 6 | kerur
# Processing Record 4 of Set 6 | jiaocheng
# Processing Record 5 of Set 6 | kaka
# Processing Record 6 of Set 6 | patiya
# Processing Record 7 of Set 6 | alegrete
# Processing Record 8 of Set 6 | zeya
# Processing Record 9 of Set 6 | strezhevoy
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | stabat
# Processing Record 13 of Set 6 | pryyutivka
# Processing Record 14 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 6 | marsh harbour
# Processing Record 16 of Set 6 | puerto boyaca
# Processing Record 17 of Set 6 | sechura
# Processing Record 18 of Set 6 | beyneu
# Processing Record 19 of Set 6 | venezuela
# Processing Record 20 of Set 6 | mukhen
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | buala
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | ornskoldsvik
# Processing Record 25 of Set 6 | tazovskiy
# Processing Record 26 of Set 6 | benguela
# Processing Record 27 of Set 6 | sarab
# Processing Record 28 of Set 6 | yaypan
# Processing Record 29 of Set 6 | talnakh
# Processing Record 30 of Set 6 | guadalupe y calvo
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | honningsvag
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | pyapon
# Processing Record 36 of Set 6 | urumqi
# Processing Record 37 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 6 | nalut
# Processing Record 39 of Set 6 | caico
# Processing Record 40 of Set 6 | urubicha
# Processing Record 41 of Set 6 | verkhoyansk
# Processing Record 42 of Set 6 | whitianga
# Processing Record 43 of Set 6 | yerbogachen
# Processing Record 44 of Set 6 | smithers
# Processing Record 45 of Set 6 | tadine
# Processing Record 46 of Set 6 | lardos
# Processing Record 47 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 6 | wanning
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | damghan
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | rio grande
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | canutama
# Processing Record 5 of Set 7 | celestun
# Processing Record 6 of Set 7 | shingu
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | salalah
# Processing Record 10 of Set 7 | alamosa
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | smoky lake
# Processing Record 13 of Set 7 | lasa
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | mandalgovi
# Processing Record 16 of Set 7 | ahipara
# Processing Record 17 of Set 7 | mitsamiouli
# Processing Record 18 of Set 7 | tacoronte
# Processing Record 19 of Set 7 | mao
# Processing Record 20 of Set 7 | tasiilaq
# Processing Record 21 of Set 7 | saint-joseph
# Processing Record 22 of Set 7 | wanaka
# Processing Record 23 of Set 7 | qaqortoq
# Processing Record 24 of Set 7 | prado
# Processing Record 25 of Set 7 | riccione
# Processing Record 26 of Set 7 | oktyabrskiy
# Processing Record 27 of Set 7 | birjand
# Processing Record 28 of Set 7 | lahaina
# Processing Record 29 of Set 7 | eyl
# Processing Record 30 of Set 7 | oum hadjer
# Processing Record 31 of Set 7 | mugur-aksy
# Processing Record 32 of Set 7 | flic en flac
# Processing Record 33 of Set 7 | bay roberts
# Processing Record 34 of Set 7 | vytegra
# Processing Record 35 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 7 | armidale
# Processing Record 37 of Set 7 | nabire
# Processing Record 38 of Set 7 | grindavik
# Processing Record 39 of Set 7 | khokhlovo
# Processing Record 40 of Set 7 | manggar
# Processing Record 41 of Set 7 | kemijarvi
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | piltene
# Processing Record 44 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 7 | gashua
# Processing Record 46 of Set 7 | kijang
# Processing Record 47 of Set 7 | lagos
# Processing Record 48 of Set 7 | panuco
# Processing Record 49 of Set 7 | mareeba
# Processing Record 50 of Set 7 | de aar
# Processing Record 1 of Set 8 | norman wells
# Processing Record 2 of Set 8 | rongcheng
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | sipkovica
# Processing Record 5 of Set 8 | porosozero
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | uroteppa
# City not found. Skipping...
# Processing Record 8 of Set 8 | pozo colorado
# Processing Record 9 of Set 8 | wajima
# Processing Record 10 of Set 8 | lowestoft
# Processing Record 11 of Set 8 | olafsvik
# Processing Record 12 of Set 8 | north bend
# Processing Record 13 of Set 8 | roald
# Processing Record 14 of Set 8 | sur
# Processing Record 15 of Set 8 | jiutai
# Processing Record 16 of Set 8 | turukhansk
# Processing Record 17 of Set 8 | ossora
# Processing Record 18 of Set 8 | karlskrona
# Processing Record 19 of Set 8 | hervey bay
# Processing Record 20 of Set 8 | conil
# Processing Record 21 of Set 8 | mayo
# Processing Record 22 of Set 8 | sola
# Processing Record 23 of Set 8 | komsomolskiy
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | ferme-neuve
# Processing Record 26 of Set 8 | chicama
# Processing Record 27 of Set 8 | hammerfest
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | muisne
# Processing Record 30 of Set 8 | vari
# Processing Record 31 of Set 8 | lincoln
# Processing Record 32 of Set 8 | porto walter
# Processing Record 33 of Set 8 | segou
# Processing Record 34 of Set 8 | zenzeli
# Processing Record 35 of Set 8 | taree
# Processing Record 36 of Set 8 | tahoua
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | tambilil
# Processing Record 39 of Set 8 | pevek
# Processing Record 40 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 8 | miranda
# Processing Record 42 of Set 8 | mae sai
# Processing Record 43 of Set 8 | launceston
# Processing Record 44 of Set 8 | richards bay
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | cayenne
# Processing Record 47 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | cabo san lucas
# Processing Record 1 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 9 | la union
# Processing Record 3 of Set 9 | rybinsk
# Processing Record 4 of Set 9 | saint-pierre
# Processing Record 5 of Set 9 | kitui
# Processing Record 6 of Set 9 | anito
# Processing Record 7 of Set 9 | college
# Processing Record 8 of Set 9 | warrington
# Processing Record 9 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 10 of Set 9 | mosquera
# Processing Record 11 of Set 9 | lamin
# Processing Record 12 of Set 9 | padang
# Processing Record 13 of Set 9 | waitati
# Processing Record 14 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 9 | aykhal
# Processing Record 16 of Set 9 | kukmor
# Processing Record 17 of Set 9 | sibanicu
# Processing Record 18 of Set 9 | kingaroy
# Processing Record 19 of Set 9 | mizdah
# Processing Record 20 of Set 9 | sao filipe
# Processing Record 21 of Set 9 | santa fe
# Processing Record 22 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 23 of Set 9 | youghal
# Processing Record 24 of Set 9 | ostuman
# City not found. Skipping...
# Processing Record 25 of Set 9 | maniitsoq
# Processing Record 26 of Set 9 | djambala
# Processing Record 27 of Set 9 | ozernovskiy
# Processing Record 28 of Set 9 | batagay
# Processing Record 29 of Set 9 | oranjestad
# Processing Record 30 of Set 9 | contepec
# Processing Record 31 of Set 9 | palora
# Processing Record 32 of Set 9 | mahanoro
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | kaduy
# Processing Record 35 of Set 9 | miri
# Processing Record 36 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 9 | bitung
# Processing Record 38 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 9 | nuuk
# Processing Record 40 of Set 9 | kutulik
# Processing Record 41 of Set 9 | maragogi
# Processing Record 42 of Set 9 | banda aceh
# Processing Record 43 of Set 9 | zyryanka
# Processing Record 44 of Set 9 | umm lajj
# Processing Record 45 of Set 9 | duz
# City not found. Skipping...
# Processing Record 46 of Set 9 | oreanda
# City not found. Skipping...
# Processing Record 47 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 9 | sinnamary
# Processing Record 49 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 9 | sasni
# Processing Record 1 of Set 10 | nacala
# Processing Record 2 of Set 10 | opuwo
# Processing Record 3 of Set 10 | dalinghe
# City not found. Skipping...
# Processing Record 4 of Set 10 | mitu
# Processing Record 5 of Set 10 | emerald
# Processing Record 6 of Set 10 | kruisfontein
# Processing Record 7 of Set 10 | talaya
# Processing Record 8 of Set 10 | byron bay
# Processing Record 9 of Set 10 | marsa matruh
# Processing Record 10 of Set 10 | phayakkhaphum phisai
# Processing Record 11 of Set 10 | moose factory
# Processing Record 12 of Set 10 | agustin codazzi
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | gillette
# Processing Record 15 of Set 10 | may pen
# Processing Record 16 of Set 10 | moroni
# Processing Record 17 of Set 10 | bilibino
# Processing Record 18 of Set 10 | san vicente de canete
# Processing Record 19 of Set 10 | bamiantong
# Processing Record 20 of Set 10 | tinambacan
# Processing Record 21 of Set 10 | corpus christi
# Processing Record 22 of Set 10 | awbari
# Processing Record 23 of Set 10 | ifo
# Processing Record 24 of Set 10 | kuznechikha
# Processing Record 25 of Set 10 | troitskoye
# Processing Record 26 of Set 10 | mendi
# Processing Record 27 of Set 10 | parrsboro
# Processing Record 28 of Set 10 | erzin
# Processing Record 29 of Set 10 | hobyo
# Processing Record 30 of Set 10 | paita
# Processing Record 31 of Set 10 | pangai
# Processing Record 32 of Set 10 | caravelas
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | kunashak
# Processing Record 35 of Set 10 | skegness
# Processing Record 36 of Set 10 | athabasca
# Processing Record 37 of Set 10 | dongsheng
# Processing Record 38 of Set 10 | ulladulla
# Processing Record 39 of Set 10 | kapasan
# Processing Record 40 of Set 10 | tevaitoa
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | morehead
# Processing Record 43 of Set 10 | saint anthony
# Processing Record 44 of Set 10 | karratha
# Processing Record 45 of Set 10 | san quintin
# Processing Record 46 of Set 10 | beitbridge
# Processing Record 47 of Set 10 | loreto
# Processing Record 48 of Set 10 | clyde river
# Processing Record 49 of Set 10 | la sierra
# Processing Record 50 of Set 10 | porto novo
# Processing Record 1 of Set 11 | ushtobe
# Processing Record 2 of Set 11 | klyuchi
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | rawson
# Processing Record 5 of Set 11 | batesville
# Processing Record 6 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 7 of Set 11 | sirur
# Processing Record 8 of Set 11 | samarai
# Processing Record 9 of Set 11 | salinas
# Processing Record 10 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 11 of Set 11 | altay
# Processing Record 12 of Set 11 | sabya
# Processing Record 13 of Set 11 | bansda
# City not found. Skipping...
# Processing Record 14 of Set 11 | kuruman
# Processing Record 15 of Set 11 | kamenica
# Processing Record 16 of Set 11 | dabat
# Processing Record 17 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 11 | isabela
# Processing Record 19 of Set 11 | mahajanga
# Processing Record 20 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 11 | berlevag
# Processing Record 22 of Set 11 | tanout
# Processing Record 23 of Set 11 | bushehr
# Processing Record 24 of Set 11 | pokhara
# Processing Record 25 of Set 11 | timra
# Processing Record 26 of Set 11 | manavalakurichi
# Processing Record 27 of Set 11 | tual
# Processing Record 28 of Set 11 | ginda
# Processing Record 29 of Set 11 | kangaatsiaq
# Processing Record 30 of Set 11 | bazaliya
# Processing Record 31 of Set 11 | santa marta
# Processing Record 32 of Set 11 | ambositra
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | ginir
# Processing Record 36 of Set 11 | santiago de cao
# Processing Record 37 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 11 | mehran
# Processing Record 39 of Set 11 | ancud
# Processing Record 40 of Set 11 | manokwari
# Processing Record 41 of Set 11 | the valley
# Processing Record 42 of Set 11 | olari
# Processing Record 43 of Set 11 | manaskent
# Processing Record 44 of Set 11 | assiniboia
# Processing Record 45 of Set 11 | vredendal
# Processing Record 46 of Set 11 | tomatlan
# Processing Record 47 of Set 11 | marawi
# Processing Record 48 of Set 11 | berbera
# Processing Record 49 of Set 11 | savasleyka
# Processing Record 50 of Set 11 | kholodnyy
# Processing Record 1 of Set 12 | bennettsville
# Processing Record 2 of Set 12 | qeshm
# Processing Record 3 of Set 12 | uberlandia
# Processing Record 4 of Set 12 | erenhot
# Processing Record 5 of Set 12 | la asuncion
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | belmonte
# Processing Record 8 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 12 | bara
# Processing Record 10 of Set 12 | san pedro buenavista
# Processing Record 11 of Set 12 | troitsko-pechorsk
# Processing Record 12 of Set 12 | geraldton
# Processing Record 13 of Set 12 | ternate
# Processing Record 14 of Set 12 | tornio
# Processing Record 15 of Set 12 | angatuba
# Processing Record 16 of Set 12 | baghdad
# Processing Record 17 of Set 12 | mastic beach
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | veselynove
# Processing Record 20 of Set 12 | mandurah
# Processing Record 21 of Set 12 | mayumba
# Processing Record 22 of Set 12 | fort payne
# Processing Record 23 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 12 | sungaipenuh
# Processing Record 26 of Set 12 | bonavista
# Processing Record 27 of Set 12 | jalu
# Processing Record 28 of Set 12 | chelno-vershiny
# Processing Record 29 of Set 12 | vieques
# Processing Record 30 of Set 12 | cyangugu
# Processing Record 31 of Set 12 | khandyga
# Processing Record 32 of Set 12 | lavrentiya
# Processing Record 33 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 12 | kommunar
# Processing Record 35 of Set 12 | kologriv
# Processing Record 36 of Set 12 | east wenatchee bench
# Processing Record 37 of Set 12 | lugovoy
# Processing Record 38 of Set 12 | ballina
# Processing Record 39 of Set 12 | prince rupert
# Processing Record 40 of Set 12 | yaqui
# Processing Record 41 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 12 | san andres
# Processing Record 43 of Set 12 | vallenar
# Processing Record 44 of Set 12 | san carlos de bariloche
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | mujiayingzi
# Processing Record 47 of Set 12 | la palma
# Processing Record 48 of Set 12 | kolyvan
# Processing Record 49 of Set 12 | nurota
# Processing Record 50 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 1 of Set 13 | baykit
# Processing Record 2 of Set 13 | norwood
# Processing Record 3 of Set 13 | gilgit
# Processing Record 4 of Set 13 | martapura
# Processing Record 5 of Set 13 | tecoanapa
# Processing Record 6 of Set 13 | orlik
# Processing Record 7 of Set 13 | yangambi
# Processing Record 8 of Set 13 | vodnyy
# Processing Record 9 of Set 13 | aromashevo
# Processing Record 10 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 11 of Set 13 | praia
# Processing Record 12 of Set 13 | sambava
# Processing Record 13 of Set 13 | ramsar
# Processing Record 14 of Set 13 | otofuke
# Processing Record 15 of Set 13 | satellite beach
# Processing Record 16 of Set 13 | mwene-ditu
# Processing Record 17 of Set 13 | solnechnyy
# Processing Record 18 of Set 13 | merauke
# Processing Record 19 of Set 13 | colac
# Processing Record 20 of Set 13 | mackay
# Processing Record 21 of Set 13 | alekseyevsk
# Processing Record 22 of Set 13 | scalloway
# City not found. Skipping...
# Processing Record 23 of Set 13 | porto murtinho
# Processing Record 24 of Set 13 | sao gotardo
# Processing Record 25 of Set 13 | tarbagatay
# Processing Record 26 of Set 13 | pangoa
# Processing Record 27 of Set 13 | alice town
# Processing Record 28 of Set 13 | flinders
# Processing Record 29 of Set 13 | panama city
# Processing Record 30 of Set 13 | kieta
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | bell ville
# Processing Record 33 of Set 13 | norilsk
# Processing Record 34 of Set 13 | bethanien
# Processing Record 35 of Set 13 | timmins
# Processing Record 36 of Set 13 | nishihara
# Processing Record 37 of Set 13 | nurlat
# Processing Record 38 of Set 13 | moree
# Processing Record 39 of Set 13 | pontian kecil
# Processing Record 40 of Set 13 | capaci
# Processing Record 41 of Set 13 | le port
# Processing Record 42 of Set 13 | villa maria
# Processing Record 43 of Set 13 | rio gallegos
# Processing Record 44 of Set 13 | faanui
# Processing Record 45 of Set 13 | aden
# Processing Record 46 of Set 13 | methven
# Processing Record 47 of Set 13 | chisec
# Processing Record 48 of Set 13 | prieska
# Processing Record 49 of Set 13 | chabahar
# Processing Record 50 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 14 | churapcha
# Processing Record 2 of Set 14 | orsk
# Processing Record 3 of Set 14 | along
# Processing Record 4 of Set 14 | dicabisagan
# Processing Record 5 of Set 14 | kenora
# Processing Record 6 of Set 14 | sioux lookout
# Processing Record 7 of Set 14 | frankfort
# Processing Record 8 of Set 14 | port-gentil
# Processing Record 9 of Set 14 | erzincan
# Processing Record 10 of Set 14 | boulder city
# Processing Record 11 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 14 | port hardy
# Processing Record 13 of Set 14 | olovo
# Processing Record 14 of Set 14 | paramonga
# Processing Record 15 of Set 14 | takanabe
# Processing Record 16 of Set 14 | alice springs
# Processing Record 17 of Set 14 | mushabani
# Processing Record 18 of Set 14 | auki
# Processing Record 19 of Set 14 | plettenberg bay
# Processing Record 20 of Set 14 | farah
# Processing Record 21 of Set 14 | monze
# Processing Record 22 of Set 14 | victor harbor
# Processing Record 23 of Set 14 | namibe
# Processing Record 24 of Set 14 | merrill
# Processing Record 25 of Set 14 | tessalit
# Processing Record 26 of Set 14 | omboue
# Processing Record 27 of Set 14 | san jeronimo
# Processing Record 28 of Set 14 | awjilah
# Processing Record 29 of Set 14 | abu samrah
# Processing Record 30 of Set 14 | pospelikha
# Processing Record 31 of Set 14 | ampanihy
# Processing Record 32 of Set 14 | baculin
# Processing Record 33 of Set 14 | kalmunai
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | vilyuysk
# Processing Record 36 of Set 14 | baiao
# Processing Record 37 of Set 14 | haikou
# Processing Record 38 of Set 14 | tommot
# Processing Record 39 of Set 14 | apiai
# Processing Record 40 of Set 14 | la paz
# Processing Record 41 of Set 14 | champerico
# Processing Record 42 of Set 14 | babaeski
# Processing Record 43 of Set 14 | seropedica
# Processing Record 44 of Set 14 | bambanglipuro
# Processing Record 45 of Set 14 | coquimbo
# Processing Record 46 of Set 14 | bac lieu
# Processing Record 47 of Set 14 | sakakah
# Processing Record 48 of Set 14 | lazaro cardenas
# Processing Record 49 of Set 14 | vila
# Processing Record 50 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 15 | talcahuano
# Processing Record 2 of Set 15 | shache
# Processing Record 3 of Set 15 | santa comba
# Processing Record 4 of Set 15 | vila velha
# Processing Record 5 of Set 15 | bolobo
# Processing Record 6 of Set 15 | gautier
# Processing Record 7 of Set 15 | gumdag
# Processing Record 8 of Set 15 | coaldale
# Processing Record 9 of Set 15 | san patricio
# Processing Record 10 of Set 15 | hailey
# Processing Record 11 of Set 15 | laizhou
# Processing Record 12 of Set 15 | beringovskiy
# Processing Record 13 of Set 15 | north platte
# Processing Record 14 of Set 15 | camana
# Processing Record 15 of Set 15 | labuhan
# Processing Record 16 of Set 15 | nove straseci
# Processing Record 17 of Set 15 | weligama
# Processing Record 18 of Set 15 | altagracia de orituco
# Processing Record 19 of Set 15 | bontang
# Processing Record 20 of Set 15 | kirakira
# Processing Record 21 of Set 15 | ibra
# Processing Record 22 of Set 15 | thano bula khan
# City not found. Skipping...
# Processing Record 23 of Set 15 | jieshi
# Processing Record 24 of Set 15 | chinchani
# Processing Record 25 of Set 15 | narsaq
# Processing Record 26 of Set 15 | contamana
# Processing Record 27 of Set 15 | ciudad bolivar
# Processing Record 28 of Set 15 | redmond
# Processing Record 29 of Set 15 | cortez
# Processing Record 30 of Set 15 | belyy yar
# Processing Record 31 of Set 15 | korschenbroich
# Processing Record 32 of Set 15 | nouadhibou
# Processing Record 33 of Set 15 | roma
# Processing Record 34 of Set 15 | nisia floresta
# Processing Record 35 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 15 | fethiye
# Processing Record 37 of Set 15 | bacolod
# Processing Record 38 of Set 15 | watertown
# Processing Record 39 of Set 15 | ketchikan
# Processing Record 40 of Set 15 | kousseri
# Processing Record 41 of Set 15 | chinsali
# Processing Record 42 of Set 15 | naze
# Processing Record 43 of Set 15 | blagoyevo
# Processing Record 44 of Set 15 | sayyan
# Processing Record 45 of Set 15 | taltal
# Processing Record 46 of Set 15 | sidi ali
# Processing Record 47 of Set 15 | lakes entrance
# Processing Record 48 of Set 15 | dickinson
# Processing Record 49 of Set 15 | aberdeen
# Processing Record 50 of Set 15 | rapid valley
# Processing Record 1 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 16 | paris
# Processing Record 3 of Set 16 | severnyy
# Processing Record 4 of Set 16 | juneau
# Processing Record 5 of Set 16 | cabedelo
# Processing Record 6 of Set 16 | matagami
# Processing Record 7 of Set 16 | yurimaguas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create Weather DataFrame
city_data_df=pd.DataFrame(citi_data)

# %%
# Rearrange the column
new_column_order=["City","Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
